# %% [markdown]
# # Demo EcoAssist AI Pro
# Notebook de demostración del sistema RAG simulado.

# %%
import sys, os
sys.path.append(os.path.abspath('../src'))
from rag_core import answer_order_query, answer_return_query

# %%
answer_order_query('Necesito saber el estado del pedido 12347')

# %%
answer_return_query('Shampoo natural', 'higiene', 5, 'cerrado')
